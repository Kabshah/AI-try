# %% [markdown]
# <a href="https://colab.research.google.com/github/Kabshah/smithub/blob/main/Kaggle_Encoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('BMW sales data (2010-2024) (1).csv')

# %%
df.head()
# Out:
#       Model  Year         Region  Color Fuel_Type Transmission  Engine_Size_L  \
# 0  5 Series  2016           Asia    Red    Petrol       Manual            3.5
# 1        i8  2013  North America    Red    Hybrid    Automatic            1.6
# 2  5 Series  2022  North America   Blue    Petrol    Automatic            4.5
# 3        X3  2024    Middle East   Blue    Petrol    Automatic            1.7
# 4  7 Series  2020  South America  Black    Diesel       Manual            2.1
#
#    Mileage_KM  Price_USD  Sales_Volume Sales_Classification
# 0      151748      98740          8300                 High
# 1      121671      79219          3428                  Low
# 2       10991     113265          6994                  Low
# 3       27255      60971          4047                  Low
# 4      122131      49898          3080                  Low

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Model                 50000 non-null  object
#  1   Year                  50000 non-null  int64
#  2   Region                50000 non-null  object
#  3   Color                 50000 non-null  object
#  4   Fuel_Type             50000 non-null  object
#  5   Transmission          50000 non-null  object
#  6   Engine_Size_L         50000 non-null  float64
#  7   Mileage_KM            50000 non-null  int64
#  8   Price_USD             50000 non-null  int64
#  9   Sales_Volume          50000 non-null  int64
#  10  Sales_Classification  50000 non-null  object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 4.2+ MB

# %%
df['Fuel_Type'].unique()
# Out:
# array(['Petrol', 'Hybrid', 'Diesel', 'Electric'], dtype=object)

# %%
df['Transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
df['Model'].unique()
# Out:
# array(['5 Series', 'i8', 'X3', '7 Series', 'M5', '3 Series', 'X1', 'M3',
#        'X5', 'i3', 'X6'], dtype=object)

# %%
df['Sales_Classification'].unique()
# Out:
# array(['High', 'Low'], dtype=object)

# %%
df['Region'].unique()
# Out:
# array(['Asia', 'North America', 'Middle East', 'South America', 'Europe',
#        'Africa'], dtype=object)

# %% [markdown]
# **Label  Encoding**

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()
df['Fuel_Type_Encoded'] = encoder.fit_transform(df['Fuel_Type'])

# %%
print("Classes: ", encoder.classes_)
# Out:
# Classes:  ['Diesel' 'Electric' 'Hybrid' 'Petrol']

# %%
df[['Fuel_Type', 'Fuel_Type_Encoded']].head(10)
# Out:
#   Fuel_Type  Fuel_Type_Encoded
# 0    Petrol                  3
# 1    Hybrid                  2
# 2    Petrol                  3
# 3    Petrol                  3
# 4    Diesel                  0
# 5    Diesel                  0
# 6    Diesel                  0
# 7    Diesel                  0
# 8    Diesel                  0
# 9  Electric                  1

# %%
Encoder = LabelEncoder()
df['Transmission_Encoded'] = encoder.fit_transform(df['Transmission'])

# %%
print("Classes: ", encoder.classes_)
# Out:
# Classes:  ['Automatic' 'Manual']

# %%
df[['Transmission', 'Transmission_Encoded']].head(10)
# Out:
#   Transmission  Transmission_Encoded
# 0       Manual                     1
# 1    Automatic                     0
# 2    Automatic                     0
# 3    Automatic                     0
# 4       Manual                     1
# 5       Manual                     1
# 6       Manual                     1
# 7    Automatic                     0
# 8    Automatic                     0
# 9       Manual                     1
