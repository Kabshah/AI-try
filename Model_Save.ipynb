# %% [markdown]
# <a href="https://colab.research.google.com/github/Kabshah/AI-try/blob/main/Model_Save.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# Upload the model file
uploaded = files.upload()
# Out:
#      <input type="file" id="files-51c9c41f-4bff-4d66-b2a7-735e5515f01c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-51c9c41f-4bff-4d66-b2a7-735e5515f01c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from tensorflow.keras.models import load_model

# Load model
model = load_model("fire_dataset.h5")

print("✅ Model loaded successfully")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ✅ Model loaded successfully

# %%
uploaded = files.upload()

# Get the filename
img_path = list(uploaded.keys())[0]
print("Uploaded image:", img_path)
# Out:
#      <input type="file" id="files-4f8a90e4-614a-4fa5-93f7-3e609cd4e98f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4f8a90e4-614a-4fa5-93f7-3e609cd4e98f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

# Load image and resize
img = image.load_img(img_path, target_size=(150, 150))

# Convert to array and preprocess
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0) / 255.0

# %%
# Predict
prediction = model.predict(img_array)

# Interpret result
label = "Non-fire" if prediction[0][0] > 0.5 else "Fire"
print("Prediction:", label)

# Show image with label
plt.imshow(image.load_img(img_path))
plt.axis("off")
plt.title(f"Prediction: {label}")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Prediction: Fire
